# %% [markdown]
# Importamos los datos necesarios para nuestro proyecto. Nos conectamos a MongoDB.

# %%
#Importamos los datos

from pymongo import MongoClient
import pandas as pd
client = MongoClient("mongodb://localhost:27017/")
db = client.db_companies

# %%
companies = db.companies.find()
data_companies = pd.DataFrame(companies)
data_companies.head()
# Out:
#                         _id       name permalink  \
# 0  52cdef7c4bab8bd675297d8b  AdventNet      abc3
# 1  52cdef7c4bab8bd675297d8a   Wetpaint      abc2
# 2  52cdef7c4bab8bd675297d8c       Zoho      abc4
# 3  52cdef7c4bab8bd675297d90    Postini   postini
# 4  52cdef7c4bab8bd675297d8d       Digg      digg
#
#                                 crunchbase_url             homepage_url  \
# 0  http://www.crunchbase.com/company/adventnet     http://adventnet.com
# 1   http://www.crunchbase.com/company/wetpaint  http://wetpaint-inc.com
# 2       http://www.crunchbase.com/company/zoho          http://zoho.com
# 3    http://www.crunchbase.com/company/postini       http://postini.com
# 4       http://www.crunchbase.com/company/digg      http://www.digg.com
#
#                       blog_url                     blog_feed_url  \
# 0
# 1  http://digitalquarters.net/  http://digitalquarters.net/feed/
# 2       http://blogs.zoho.com/        http://blogs.zoho.com/feed
# 3
# 4        http://blog.digg.com/   http://blog.digg.com/?feed=rss2
#
#   twitter_username category_code  number_of_employees  ...  \
# 0     manageengine    enterprise                600.0  ...
# 1  BachelrWetpaint           web                 47.0  ...
# 2             zoho      software               1600.0  ...
# 3             None           web                  NaN  ...
# 4             digg          news                 60.0  ...
#
#                                         video_embeds  \
# 0                                                 []
# 1                                                 []
# 2  [{'embed_code': '<object width="430" height="2...
# 3                                                 []
# 4  [{'embed_code': '<embed src="http://blip.tv/pl...
#
#                                          screenshots  \
# 0  [{'available_sizes': [[[150, 94], 'assets/imag...
# 1  [{'available_sizes': [[[150, 86], 'assets/imag...
# 2                                                 []
# 3                                                 []
# 4  [{'available_sizes': [[[117, 150], 'assets/ima...
#
#                                       external_links partners founded_month  \
# 0                                                 []       []           NaN
# 1  [{'external_url': 'http://www.geekwire.com/201...       []          10.0
# 2  [{'external_url': 'http://www.online-tech-tips...       []           9.0
# 3                                                 []       []           6.0
# 4  [{'external_url': 'http://www.sociableblog.com...       []          10.0
#
#   founded_day deadpooled_month deadpooled_day deadpooled_url   ipo
# 0         NaN              NaN            NaN            NaN   NaN
# 1        17.0              NaN            NaN            NaN   NaN
# 2        15.0              NaN            NaN            NaN   NaN
# 3         2.0              NaN            NaN           None  None
# 4        11.0              NaN            NaN           None  None
#
# [5 rows x 42 columns]

# %% [markdown]
# Contabilizamos los tipos de empresas que aparecen en el dataframe para extraer con facilidad las empresas que nos interesan. No olvidemos que nos hemos especializado en el sector de los videojuegos y, por tanto, los intereses de nuestros trabajadores serán cercanos al sector al que pertenecen.

# %%
data_companies['category_code'].value_counts()
# Out:
# web                 3787
# software            2736
# games_video         1083
# mobile              1018
# other                986
# advertising          928
# enterprise           742
# ecommerce            688
# consulting           637
# network_hosting      626
# public_relations     533
# search               394
# biotech              373
# hardware             368
# cleantech            305
# semiconductor        167
# security             156
# analytics             66
# social                49
# finance               49
# news                  48
# education             36
# music                 33
# messaging             30
# legal                 25
# medical               25
# travel                25
# photo_video           23
# health                23
# manufacturing         19
# sports                13
# fashion               10
# real_estate           10
# automotive             9
# hospitality            8
# transportation         7
# nanotech               5
# design                 4
# nonprofit              4
# local                  1
# government             1
# Name: category_code, dtype: int64

# %% [markdown]
# Filtramos los datos que nos interesan acerca de las empresas de las que ya conocemos el sector. Evitamos las empresas con bajos ingresos.

# %%
companies_flt = db.companies.find({
    "founded_year" : {"$gte" : 2006},
    "total_money_raised" : {
        '$nin': ["$100k", "$0", "$500k"]},
    "category_code":{
        "$in":["design", 'software', 'web', 'games video', 'hadware', 'mobile']}})

companies_flt = pd.DataFrame(companies_flt)
companies_flt.shape
# Out:
# (749, 42)

# %% [markdown]
# Creamos el geopoint necesario para cada empresa extrayendo una longitud y una latitud. Excluimos los NaN.

# %%
import numpy as np

def geopoint(x): 
    for row_companies in x:
        
        latitude = row_companies["latitude"]
        longitude = row_companies["longitude"]
        if latitude is None:
            return np.NaN
        return {"type": "Point", "coordinates": [longitude,latitude]}


companies_flt['geo']=companies_flt['offices'].apply(geopoint)
companies_flt.dropna(subset=['geo'], inplace = True)

# %%
comp_cl = companies_flt[["acquisition","category_code","created_at","description",
"founded_year","name","number_of_employees","offices","overview","products","total_money_raised", "geo"]]

comp_cl.to_json(r'dataset_def.json', orient='records')

# %%
companies_flt['total_money_raised'].value_counts()
# Out:
# $1M       16
# $4M       14
# $5M       14
# $2M       12
# $200k      9
#           ..
# $21.7M     1
# $9.65M     1
# $169k      1
# $5.97M     1
# $3.45M     1
# Name: total_money_raised, Length: 319, dtype: int64

# %% [markdown]
# Cargamos la base de datos a la que previamente hemos creado un geoíndice en MongoDB.

# %%
#cargando base de datos seleccionada con geoíndice
companies_2 = db.companies_def.find()
dc2 = pd.DataFrame(companies_2)
dc2.shape
# Out:
# (565, 13)

# %% [markdown]
# Estudiamos las ciudades más interesantes para crear nuestra empresa

# %%
dc2["cities"] = [element[0]["city"] for element in dc2["offices"]]
dc2["cities"].value_counts()
# Out:
# San Francisco     89
# New York          41
# Palo Alto         19
# Austin            15
# London            14
#                   ..
# Atlantic Beach     1
# Wurzberg           1
# McLean             1
# Bath               1
# SAN FRANCISCO      1
# Name: cities, Length: 207, dtype: int64

# %%
#integrando la fn geonear

def geonear(geopoint, maxdistance=1000):
    return db.companies_def.find({
        "geo":{
            "$near":{
                "$geometry":geopoint,
                "$maxDistance":maxdistance
            }}})

# %%
# Con el near, quiero pasarle un geopoint y me devuelve una lista de empresas 
#elijo San Francisco porque tiene una potente empresa de diseño en la ciudad

sanfrancisco = {'type': 'Point', 'coordinates': [-122.431297, 37.773972]}
sanfranciscogp = pd.DataFrame(geonear(sanfrancisco, 10000))
sanfranciscogp
# Out:
#                          _id  \
# 0   5d862a24752696fefdd05463
# 1   5d862a24752696fefdd05483
# 2   5d862a24752696fefdd0533a
# 3   5d862a24752696fefdd05441
# 4   5d862a24752696fefdd054d3
# ..                       ...
# 74  5d862a24752696fefdd05458
# 75  5d862a24752696fefdd0547c
# 76  5d862a24752696fefdd05525
# 77  5d862a24752696fefdd053c1
# 78  5d862a24752696fefdd05385
#
#                                           acquisition category_code  \
# 0                                                None      software
# 1                                                None      software
# 2   {'price_amount': None, 'price_currency_code': ...           web
# 3                                                None           web
# 4                                                None           web
# ..                                                ...           ...
# 74  {'price_amount': None, 'price_currency_code': ...           web
# 75  {'price_amount': None, 'price_currency_code': ...           web
# 76                                               None           web
# 77                                               None      software
# 78                                               None           web
#
#                       created_at                         description  \
# 0   Mon Sep 08 22:16:49 UTC 2008     Screen Writing Software Company
# 1   Mon Sep 08 22:16:49 UTC 2008     Screen Writing Software Company
# 2   Mon Oct 08 10:17:18 UTC 2007        Social software applications
# 3   Wed Jul 30 21:45:37 UTC 2008  Rich Media Internet Communications
# 4   Tue Dec 30 22:18:00 UTC 2008        Lifestyle Brand Site Hosting
# ..                           ...                                 ...
# 74  Wed Aug 27 06:32:49 UTC 2008              Rating and review site
# 75  Wed Aug 27 06:32:49 UTC 2008              Rating and review site
# 76  Sun May 03 22:10:19 UTC 2009
# 77  Thu Mar 13 21:01:28 UTC 2008                    software company
# 78  Sat Nov 17 14:24:23 UTC 2007         Multiplayer Networked Games
#
#     founded_year          name  number_of_employees  \
# 0           2007      Scripped                  4.0
# 1           2007      Scripped                  4.0
# 2           2007       Seesmic                 13.0
# 3           2008         Zorap                  2.0
# 4           2007  Fuego Nation                  NaN
# ..           ...           ...                  ...
# 74          2007     GoodGuide                 10.0
# 75          2007     GoodGuide                 10.0
# 76          2008     Kidlandia                  NaN
# 77          2007       Elastra                  NaN
# 78          2007    GameLayers                  5.0
#
#                                               offices  \
# 0   [{'description': None, 'address1': None, 'addr...
# 1   [{'description': None, 'address1': None, 'addr...
# 2   [{'description': '', 'address1': '1550 Bryant ...
# 3   [{'description': '', 'address1': '', 'address2...
# 4   [{'description': '', 'address1': '', 'address2...
# ..                                                ...
# 74  [{'description': '', 'address1': '', 'address2...
# 75  [{'description': '', 'address1': '', 'address2...
# 76  [{'description': '', 'address1': '1360 Montgom...
# 77  [{'description': 'HQ', 'address1': '160 Pacifi...
# 78  [{'description': None, 'address1': '1 Lombard ...
#
#                                              overview  \
# 0   <p>Scripped provides web-based screenwriting s...
# 1   <p>Scripped provides web-based screenwriting s...
# 2   <p>Seesmic is a powerful suite of social media...
# 3   <p>Zorap enables real-time participatory event...
# 4   <p>Fuego Nation was founded to build a social ...
# ..                                                ...
# 74  <p>GoodGuide.com provides free and easy access...
# 75  <p>GoodGuide.com provides free and easy access...
# 76  <p>Kidlandia is a new web destination where pa...
# 77  <p><a href="http://www.elastra.com" title="Ela...
# 78  <p>GameLayers Inc was a small game design comp...
#
#                                              products total_money_raised  \
# 0                                                  []              $700k
# 1                                                  []              $700k
# 2   [{'name': 'Seesmic', 'permalink': 'seesmic'}, ...               $16M
# 3   [{'name': 'Zorap.com', 'permalink': 'zorap-web...             $2.25M
# 4                                                  []              $1.5M
# ..                                                ...                ...
# 74                                                 []             $14.2M
# 75                                                 []             $14.2M
# 76                                                 []             $3.23M
# 77  [{'name': 'Cloud Server', 'permalink': 'cloud-...             $14.6M
# 78  [{'name': 'PMOG', 'permalink': 'pmog'}, {'name...                $2M
#
#                                                   geo
# 0   {'type': 'Point', 'coordinates': [-122.4194155...
# 1   {'type': 'Point', 'coordinates': [-122.4194155...
# 2   {'type': 'Point', 'coordinates': [-122.419204,...
# 3   {'type': 'Point', 'coordinates': [-122.419204,...
# 4   {'type': 'Point', 'coordinates': [-122.419204,...
# ..                                                ...
# 74  {'type': 'Point', 'coordinates': [-122.4000032...
# 75  {'type': 'Point', 'coordinates': [-122.4000032...
# 76  {'type': 'Point', 'coordinates': [-122.4043215...
# 77  {'type': 'Point', 'coordinates': [-122.391843,...
# 78  {'type': 'Point', 'coordinates': [-122.402468,...
#
# [79 rows x 13 columns]

# %% [markdown]
# Recurro a la API de Google para cargar las cafeterías de la ciudad elegida con cuidado de no incluir la key de la API en mi proyecto y hacerla visible a cualquier persona.

# %%
from pymongo import MongoClient
import pandas as pd
import numpy as np
import requests
import os
#from dotenv import load_dotenv

# %%
from dotenv import load_dotenv
load_dotenv()
key = os.getenv('key')
response = requests.get(key)
sb = response.json()

# %%
def starbucks(lugares):
    names=[]
    lats=[]
    long=[]
    for place in lugares["results"]:
        names.append(place["name"])
        lats.append(place["geometry"]["location"]["lat"])
        long.append(place["geometry"]["location"]["lng"])
    dictstarbucks = {"name":names, "latitude":lats, "longitude":long}
    return pd.DataFrame(dictstarbucks)
datastarbucks = starbucks(sb)
datastarbucks.head()
# Out:
#         name   latitude   longitude
# 0  Starbucks  37.806565 -122.420425
# 1  Starbucks  37.778262 -122.415038
# 2  Starbucks  37.784124 -122.407653
# 3  Starbucks  37.797718 -122.401083
# 4  Starbucks  37.786146 -122.409094

# %% [markdown]
# Trato de encontrar un punto idóneo desde donde cargará el mapa creando una coordenada producto de las coordenadas medias de todas las cafeterías

# %%
dl = datastarbucks['latitude'].mean()
dlon =  datastarbucks['longitude'].mean()
location_point= dl, dlon
location_point
# Out:
# (37.78597868, -122.41355412000003)

# %% [markdown]
# Creo una columna a la que nombro 'coordenadas' para tener la latitud y la longitud en un formato más accesible

# %%
def latcomp(latitude):
    return latitude.get('coordinates')
    
    
sanfranciscogp['coordenadas']=sanfranciscogp['geo'].apply(latcomp)
sanfranciscogp
# Out:
#                          _id  \
# 0   5d862a24752696fefdd05463
# 1   5d862a24752696fefdd05483
# 2   5d862a24752696fefdd0533a
# 3   5d862a24752696fefdd05441
# 4   5d862a24752696fefdd054d3
# ..                       ...
# 74  5d862a24752696fefdd05458
# 75  5d862a24752696fefdd0547c
# 76  5d862a24752696fefdd05525
# 77  5d862a24752696fefdd053c1
# 78  5d862a24752696fefdd05385
#
#                                           acquisition category_code  \
# 0                                                None      software
# 1                                                None      software
# 2   {'price_amount': None, 'price_currency_code': ...           web
# 3                                                None           web
# 4                                                None           web
# ..                                                ...           ...
# 74  {'price_amount': None, 'price_currency_code': ...           web
# 75  {'price_amount': None, 'price_currency_code': ...           web
# 76                                               None           web
# 77                                               None      software
# 78                                               None           web
#
#                       created_at                         description  \
# 0   Mon Sep 08 22:16:49 UTC 2008     Screen Writing Software Company
# 1   Mon Sep 08 22:16:49 UTC 2008     Screen Writing Software Company
# 2   Mon Oct 08 10:17:18 UTC 2007        Social software applications
# 3   Wed Jul 30 21:45:37 UTC 2008  Rich Media Internet Communications
# 4   Tue Dec 30 22:18:00 UTC 2008        Lifestyle Brand Site Hosting
# ..                           ...                                 ...
# 74  Wed Aug 27 06:32:49 UTC 2008              Rating and review site
# 75  Wed Aug 27 06:32:49 UTC 2008              Rating and review site
# 76  Sun May 03 22:10:19 UTC 2009
# 77  Thu Mar 13 21:01:28 UTC 2008                    software company
# 78  Sat Nov 17 14:24:23 UTC 2007         Multiplayer Networked Games
#
#     founded_year          name  number_of_employees  \
# 0           2007      Scripped                  4.0
# 1           2007      Scripped                  4.0
# 2           2007       Seesmic                 13.0
# 3           2008         Zorap                  2.0
# 4           2007  Fuego Nation                  NaN
# ..           ...           ...                  ...
# 74          2007     GoodGuide                 10.0
# 75          2007     GoodGuide                 10.0
# 76          2008     Kidlandia                  NaN
# 77          2007       Elastra                  NaN
# 78          2007    GameLayers                  5.0
#
#                                               offices  \
# 0   [{'description': None, 'address1': None, 'addr...
# 1   [{'description': None, 'address1': None, 'addr...
# 2   [{'description': '', 'address1': '1550 Bryant ...
# 3   [{'description': '', 'address1': '', 'address2...
# 4   [{'description': '', 'address1': '', 'address2...
# ..                                                ...
# 74  [{'description': '', 'address1': '', 'address2...
# 75  [{'description': '', 'address1': '', 'address2...
# 76  [{'description': '', 'address1': '1360 Montgom...
# 77  [{'description': 'HQ', 'address1': '160 Pacifi...
# 78  [{'description': None, 'address1': '1 Lombard ...
#
#                                              overview  \
# 0   <p>Scripped provides web-based screenwriting s...
# 1   <p>Scripped provides web-based screenwriting s...
# 2   <p>Seesmic is a powerful suite of social media...
# 3   <p>Zorap enables real-time participatory event...
# 4   <p>Fuego Nation was founded to build a social ...
# ..                                                ...
# 74  <p>GoodGuide.com provides free and easy access...
# 75  <p>GoodGuide.com provides free and easy access...
# 76  <p>Kidlandia is a new web destination where pa...
# 77  <p><a href="http://www.elastra.com" title="Ela...
# 78  <p>GameLayers Inc was a small game design comp...
#
#                                              products total_money_raised  \
# 0                                                  []              $700k
# 1                                                  []              $700k
# 2   [{'name': 'Seesmic', 'permalink': 'seesmic'}, ...               $16M
# 3   [{'name': 'Zorap.com', 'permalink': 'zorap-web...             $2.25M
# 4                                                  []              $1.5M
# ..                                                ...                ...
# 74                                                 []             $14.2M
# 75                                                 []             $14.2M
# 76                                                 []             $3.23M
# 77  [{'name': 'Cloud Server', 'permalink': 'cloud-...             $14.6M
# 78  [{'name': 'PMOG', 'permalink': 'pmog'}, {'name...                $2M
#
#                                                   geo  \
# 0   {'type': 'Point', 'coordinates': [-122.4194155...
# 1   {'type': 'Point', 'coordinates': [-122.4194155...
# 2   {'type': 'Point', 'coordinates': [-122.419204,...
# 3   {'type': 'Point', 'coordinates': [-122.419204,...
# 4   {'type': 'Point', 'coordinates': [-122.419204,...
# ..                                                ...
# 74  {'type': 'Point', 'coordinates': [-122.4000032...
# 75  {'type': 'Point', 'coordinates': [-122.4000032...
# 76  {'type': 'Point', 'coordinates': [-122.4043215...
# 77  {'type': 'Point', 'coordinates': [-122.391843,...
# 78  {'type': 'Point', 'coordinates': [-122.402468,...
#
#                    coordenadas
# 0   [-122.4194155, 37.7749295]
# 1   [-122.4194155, 37.7749295]
# 2     [-122.419204, 37.775196]
# 3     [-122.419204, 37.775196]
# 4     [-122.419204, 37.775196]
# ..                         ...
# 74  [-122.4000032, 37.7983181]
# 75  [-122.4000032, 37.7983181]
# 76  [-122.4043215, 37.8017938]
# 77    [-122.391843, 37.791137]
# 78    [-122.402468, 37.803847]
#
# [79 rows x 14 columns]

# %%
# modificar latcomp para que sean 2 funcioens. una que de lat a partir de geo y otra que de lon. 
# resultando en 2 columnas nuevas tipo float

def latitudcol(latcol):
    return latcol[0]
sanfranciscogp['lat_col']=sanfranciscogp['coordenadas'].apply(latitudcol)

def longcol(lcol):
    return lcol[1]
sanfranciscogp['long_col']=sanfranciscogp['coordenadas'].apply(longcol)

sanfranciscogp
# Out:
#                          _id  \
# 0   5d862a24752696fefdd05463
# 1   5d862a24752696fefdd05483
# 2   5d862a24752696fefdd0533a
# 3   5d862a24752696fefdd05441
# 4   5d862a24752696fefdd054d3
# ..                       ...
# 74  5d862a24752696fefdd05458
# 75  5d862a24752696fefdd0547c
# 76  5d862a24752696fefdd05525
# 77  5d862a24752696fefdd053c1
# 78  5d862a24752696fefdd05385
#
#                                           acquisition category_code  \
# 0                                                None      software
# 1                                                None      software
# 2   {'price_amount': None, 'price_currency_code': ...           web
# 3                                                None           web
# 4                                                None           web
# ..                                                ...           ...
# 74  {'price_amount': None, 'price_currency_code': ...           web
# 75  {'price_amount': None, 'price_currency_code': ...           web
# 76                                               None           web
# 77                                               None      software
# 78                                               None           web
#
#                       created_at                         description  \
# 0   Mon Sep 08 22:16:49 UTC 2008     Screen Writing Software Company
# 1   Mon Sep 08 22:16:49 UTC 2008     Screen Writing Software Company
# 2   Mon Oct 08 10:17:18 UTC 2007        Social software applications
# 3   Wed Jul 30 21:45:37 UTC 2008  Rich Media Internet Communications
# 4   Tue Dec 30 22:18:00 UTC 2008        Lifestyle Brand Site Hosting
# ..                           ...                                 ...
# 74  Wed Aug 27 06:32:49 UTC 2008              Rating and review site
# 75  Wed Aug 27 06:32:49 UTC 2008              Rating and review site
# 76  Sun May 03 22:10:19 UTC 2009
# 77  Thu Mar 13 21:01:28 UTC 2008                    software company
# 78  Sat Nov 17 14:24:23 UTC 2007         Multiplayer Networked Games
#
#     founded_year          name  number_of_employees  \
# 0           2007      Scripped                  4.0
# 1           2007      Scripped                  4.0
# 2           2007       Seesmic                 13.0
# 3           2008         Zorap                  2.0
# 4           2007  Fuego Nation                  NaN
# ..           ...           ...                  ...
# 74          2007     GoodGuide                 10.0
# 75          2007     GoodGuide                 10.0
# 76          2008     Kidlandia                  NaN
# 77          2007       Elastra                  NaN
# 78          2007    GameLayers                  5.0
#
#                                               offices  \
# 0   [{'description': None, 'address1': None, 'addr...
# 1   [{'description': None, 'address1': None, 'addr...
# 2   [{'description': '', 'address1': '1550 Bryant ...
# 3   [{'description': '', 'address1': '', 'address2...
# 4   [{'description': '', 'address1': '', 'address2...
# ..                                                ...
# 74  [{'description': '', 'address1': '', 'address2...
# 75  [{'description': '', 'address1': '', 'address2...
# 76  [{'description': '', 'address1': '1360 Montgom...
# 77  [{'description': 'HQ', 'address1': '160 Pacifi...
# 78  [{'description': None, 'address1': '1 Lombard ...
#
#                                              overview  \
# 0   <p>Scripped provides web-based screenwriting s...
# 1   <p>Scripped provides web-based screenwriting s...
# 2   <p>Seesmic is a powerful suite of social media...
# 3   <p>Zorap enables real-time participatory event...
# 4   <p>Fuego Nation was founded to build a social ...
# ..                                                ...
# 74  <p>GoodGuide.com provides free and easy access...
# 75  <p>GoodGuide.com provides free and easy access...
# 76  <p>Kidlandia is a new web destination where pa...
# 77  <p><a href="http://www.elastra.com" title="Ela...
# 78  <p>GameLayers Inc was a small game design comp...
#
#                                              products total_money_raised  \
# 0                                                  []              $700k
# 1                                                  []              $700k
# 2   [{'name': 'Seesmic', 'permalink': 'seesmic'}, ...               $16M
# 3   [{'name': 'Zorap.com', 'permalink': 'zorap-web...             $2.25M
# 4                                                  []              $1.5M
# ..                                                ...                ...
# 74                                                 []             $14.2M
# 75                                                 []             $14.2M
# 76                                                 []             $3.23M
# 77  [{'name': 'Cloud Server', 'permalink': 'cloud-...             $14.6M
# 78  [{'name': 'PMOG', 'permalink': 'pmog'}, {'name...                $2M
#
#                                                   geo  \
# 0   {'type': 'Point', 'coordinates': [-122.4194155...
# 1   {'type': 'Point', 'coordinates': [-122.4194155...
# 2   {'type': 'Point', 'coordinates': [-122.419204,...
# 3   {'type': 'Point', 'coordinates': [-122.419204,...
# 4   {'type': 'Point', 'coordinates': [-122.419204,...
# ..                                                ...
# 74  {'type': 'Point', 'coordinates': [-122.4000032...
# 75  {'type': 'Point', 'coordinates': [-122.4000032...
# 76  {'type': 'Point', 'coordinates': [-122.4043215...
# 77  {'type': 'Point', 'coordinates': [-122.391843,...
# 78  {'type': 'Point', 'coordinates': [-122.402468,...
#
#                    coordenadas     lat_col   long_col
# 0   [-122.4194155, 37.7749295] -122.419415  37.774929
# 1   [-122.4194155, 37.7749295] -122.419415  37.774929
# 2     [-122.419204, 37.775196] -122.419204  37.775196
# 3     [-122.419204, 37.775196] -122.419204  37.775196
# 4     [-122.419204, 37.775196] -122.419204  37.775196
# ..                         ...         ...        ...
# 74  [-122.4000032, 37.7983181] -122.400003  37.798318
# 75  [-122.4000032, 37.7983181] -122.400003  37.798318
# 76  [-122.4043215, 37.8017938] -122.404321  37.801794
# 77    [-122.391843, 37.791137] -122.391843  37.791137
# 78    [-122.402468, 37.803847] -122.402468  37.803847
#
# [79 rows x 16 columns]

# %%
# Tienes 79 localizaciones: 

# geonear te da a partir de una geopoint una lista de empresas. Esa lista es la que tienes que agregar/agtupar. de tal forma que
# para cada geopoint tendrás una lista de la que extraer info. pe. 

# 1. la longitud de esa lista seŕa el num de empresas cercanas
# 2. sumar los empleados de cada empresa de esa lista.

# %% [markdown]
# Pinto los datos extraídos hasta la fecha en el mapa utilizando Folium

# %%
import folium
import pandas as pd
from folium.plugins import HeatMap
import requests
from folium.plugins import MeasureControl


map_starbucks = folium.Map(location=location_point, width=750, height=500, zoom_start=15)

for index, row in datastarbucks.iterrows():
    folium.CircleMarker([row['latitude'], row['longitude']],
                        radius=9,
                        popup="City: {}, latitude {}, longitude {}".format(row['name'], row['latitude'], row['longitude']),
                        fill_color="#F35C50",
                       ).add_to(map_starbucks)

latitude_companies = [i[0] for i in sanfranciscogp.coordenadas]
longitude_companies = [i[1] for i in sanfranciscogp.coordenadas]
    
for coordinate in list(zip(longitude_companies,latitude_companies)):
    
    folium.Marker(coordinate,
                        radius=5,
                        icon=folium.Icon(icon='cloud'),
                        fill_color="#F45C1", 
                       ).add_to(map_starbucks)

    '''                   
    folium.Circle(location=[40.42, -3.7],
                    radius=100
                   ).add_to(map_starbucks)
    map_starbucks.add_child(MeasureControl()) 
 '''

    #map_starbucks.save('./map_starbucks.html') # Podemos guardar nuestro mapa como un html
map_starbucks
#folium.Marker(location=[0,20], icon=folium.Icon(color='lightgray', icon='home', prefix='fa')).add_to(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
